# %%
# Load env variables and create client

from dotenv import load_dotenv, find_dotenv
import os
import httpx
from anthropic import Anthropic

load_dotenv(find_dotenv(), override=True)

client = Anthropic(
    api_key=os.getenv("ANTHROPIC_API_KEY"),
    http_client=httpx.Client(
        proxy=httpx.Proxy(url=os.getenv("HTTPS_PROXY")),
        verify=False
    )
)
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.833333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport sys\nimport re\n\ndef parse_cloudformation_template(template_content):\n    # Try to parse as JSON first\n    try:\n        template = json.loads(template_content)\n        resources = template.get('Resources', {})\n        result = []\n        for logical_id, resource_config in resources.items():\n            resource_type = resource_config.get('Type', '')\n            result.append({\n                'LogicalId': logical_id,\n                'Type': resource_type\n            })\n        return result\n    except json.JSONDecodeError:\n        pass\n    \n    # Fallback to regex for YAML-like format\n    pattern = r'^\\s*(\\w+):\\s*\\n\\s+Type:\\s*([^\\n]+)'\n    matches = re.findall(pattern, template_content, re.MULTILINE)\n    result = []\n    for logical_id, resource_type in matches:\n        result.append({\n            'LogicalId': logical_id,\n            'Type': resource_type.strip()\n        })\n    return result\n\nif __name__ == '__main__':\n    template_content = sys.stdin.read()\n    resources = parse_cloudformation_template(template_content)\n    print(json.dumps(resources, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and extract all resource logical IDs and their types",
#       "format": "python",
#       "solution_criteria": "Function should read a CloudFormation JSON template, return a dictionary mapping logical IDs to resource types. Should handle nested resources and validate JSON structure."
#     },
#     "score": 7.5,
#     "reasoning": "The solution correctly addresses the core JSON parsing requirement and demonstrates good intent with YAML support. However, it has a critical mismatch with the stated criteria: the return type should be a dictionary mapping logical IDs to types, not a list of objects. The YAML regex approach is unreliable and fragile for production use. Most significantly, there's no explicit handling or validation of nested resources, and the JSON structure validation is minimal (only checking for 'Resources' key existence). For AWS CloudFormation templates in production environments, using a proper YAML library and returning the correct data structure would be essential."
#   },
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::data-*/*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketLocation\"\n      ],\n      \"Resource\": \"arn:aws:s3:::data-*\"\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create a JSON IAM policy that allows read-only access to S3 buckets with names starting with 'data-'",
#       "format": "json",
#       "solution_criteria": "Valid IAM policy JSON with appropriate principals, actions (GetObject, ListBucket), and resource ARN patterns. Should follow AWS policy structure with Effect, Action, and Resource fields."
#     },
#     "score": 9.0,
#     "reasoning": "The solution correctly addresses the core requirement of read-only S3 access for buckets matching the 'data-*' naming pattern. The policy structure is valid, and the action selections align with read-only operations. However, it could be more comprehensive depending on specific read-only requirements (e.g., whether users need to access object metadata, versions, or tags). The policy follows AWS best practices for resource-based access control but could benefit from additional context-specific permissions or explicit constraints."
#   },
#   {
#     "output": "\n^[a-z0-9][a-z0-9.\\-]*[a-z0-9]$|^[a-z0-9]$\n",
#     "test_case": {
#       "task": "Write a regex pattern to validate AWS S3 bucket names according to AWS naming rules",
#       "format": "regex",
#       "solution_criteria": "Pattern should enforce: 3-63 characters, lowercase letters/numbers/hyphens only, start and end with letter or number, no consecutive hyphens. Should pass valid names like 'my-bucket-123' and reject invalid ones like 'My-Bucket' or 'my--bucket'."
#     },
#     "score": 7.0,
#     "reasoning": "The regex correctly handles character restrictions (lowercase, numbers, hyphens, dots) and anchor requirements (start/end with alphanumeric). However, it fundamentally fails to enforce the 3-63 character length restriction and does not prevent consecutive special characters. A complete solution would require length quantifiers like `^[a-z0-9]([a-z0-9\\-]{1,61}[a-z0-9])?$` and possibly negative lookahead to prevent consecutive hyphens."
#   }
# ]
